# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

from sklearn.preprocessing import StandardScaler
import seaborn as sns
sns.set()

# %%
df = pd.read_csv("C:\\Users\\thakk\\Downloads\\diabetes_data_upload.csv")
bmi = pd.read_csv("C:\\Users\\thakk\\Downloads\\bmi.csv")

# %%
df['BMI'] = bmi['BMI']

# %%
df
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
# ...

# %%
df['Age_categorization'] = pd.cut(df['Age'], bins = 2 , labels=["Youngster", "Aged"])

# %%
df.head()
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class  BMI  \
# ...

# %%
df1 = df.drop(["Age"], axis =1)

# %%
df1.head()
# Out:
#   Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   Male       No        Yes                 No      Yes         No
# 1   Male       No         No                 No      Yes         No
# 2   Male      Yes         No                 No      Yes        Yes
# 3   Male       No         No                Yes      Yes        Yes
# 4   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class  BMI  \
# ...

# %%
df2 = StandardScaler().fit_transform(df1[['BMI']])

# %%
df2
# Out:
# array([[-0.60401385],
#        [ 0.59342115],
#        [-1.32247484],
#        [-1.08298784],
#        [ 0.11444715],
#        [ 0.23419065],
#        [-0.72375735],
#        [-0.12503985],
#        [-1.32247484],
#        [-0.24478335],
#        [-0.12503985],
#        [-0.36452685],
#        [ 1.55136915],
#        [ 0.83290815],
#        [-0.00529635],
#        [-1.68170534],
#        [ 1.19213865],
#        [-0.12503985],
#        [ 0.35393415],
#        [-1.32247484],
#        [ 0.35393415],
#        [ 0.11444715],
#        [-0.00529635],
#        [-0.24478335],
#        [-0.72375735],
#        [-1.44221834],
#        [ 1.79085615],
#        [ 1.19213865],
#        [-1.08298784],
#        [-0.72375735],
#        [ 1.19213865],
#        [-0.00529635],
#        [-0.48427035],
#        [ 0.59342115],
#        [-0.36452685],
#        [-0.12503985],
#        [ 0.59342115],
#        [-1.44221834],
#        [ 0.59342115],
#        [-0.96324434],
#        [ 1.67111265],
# ...
